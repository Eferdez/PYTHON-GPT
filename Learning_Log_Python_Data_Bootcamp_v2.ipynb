# %% [markdown]
# # 🧭 Python Data Bootcamp — Learning Log
# ### Student: **Emiliano Fernández**
# Duración total: 6 semanas · 4 horas/día · 144 horas
# Objetivo: Registrar tu progreso, métricas de aprendizaje y reflexiones semanales.
#
# > **Cómo usar este log:**
# > - Abrilo cada día después de estudiar.
# > - Escribí tus aprendizajes, dificultades y próximos pasos.
# > - Cada semana completá el resumen y autoevaluación.

# %% [markdown]
# ## 📅 Registro diario
# Usá este formato cada día (copiá y pegá el bloque).

# %% [markdown]
# ### Día X — [Tema]
# ⏰ Horas dedicadas:
# 📘 Conceptos aprendidos:
# 💻 Qué practiqué / código ejecutado:
# 🚧 Dificultades:
# ✨ Qué me salió bien:
# 🎯 Meta para mañana:

# %% [markdown]
# ## 📈 Progreso semanal
# Evaluá tus avances con puntaje 1–5 y comentarios breves.

# %% [markdown]
# | Semana | Comprensión teórica | Aplicación práctica | Organización | Motivación | Comentarios |
# |:--:|:--:|:--:|:--:|:--:|:--|
# | 1 |  |  |  |  |  |
# | 2 |  |  |  |  |  |
# | 3 |  |  |  |  |  |
# | 4 |  |  |  |  |  |
# | 5 |  |  |  |  |  |
# | 6 |  |  |  |  |  |

# %% [markdown]
# ## 🧩 Reflexión final

# %% [markdown]
# - ¿Qué herramientas domino con seguridad?
# - ¿Qué necesito reforzar antes de postularme?
# - ¿Qué proyectos incluiría en mi portfolio?
# - ¿Qué habilidades blandas desarrollé (organización, comunicación, resolución de problemas)?
# - Mi frase resumen del bootcamp:

# %% [markdown]
# ## 📊 Progress Dashboard (visual summary)
#
# Actualizá los valores de `hours` y `motivation` cada domingo y ejecutá la celda para ver tu progreso.

# %%
import matplotlib.pyplot as plt

weeks = ["W1","W2","W3","W4","W5","W6"]
hours = [0, 0, 0, 0, 0, 0]        # ← edit with your actual weekly study hours
motivation = [0, 0, 0, 0, 0, 0]   # ← edit with your weekly motivation (1–5)

fig, ax1 = plt.subplots(figsize=(7,4))

ax1.bar(weeks, hours, label="Hours studied", alpha=0.7)
ax1.set_ylabel("Hours")
ax1.set_xlabel("Weeks")
ax1.set_ylim(0, max(30, max(hours, default=0) + 5))

ax2 = ax1.twinx()
ax2.plot(weeks, motivation, marker="o", label="Motivation (1–5)")
ax2.set_ylabel("Motivation (1–5)")
ax2.set_ylim(0, 5)

fig.suptitle("Learning Progress Overview – Emi Fernández")
fig.tight_layout()
plt.show()
